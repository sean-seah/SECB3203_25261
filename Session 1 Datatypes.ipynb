# %% [markdown]
# <a href="https://colab.research.google.com/github/sean-seah/SECB3203_25261/blob/Lesson-1/Session%201%20Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style='text-align: center;'> Data types </p>

# %%
# %%html
# <style>
#     table {
#         display: inline-block
#    }
# </style>
# Out:
# <style>
#     table {
#         display: inline-block
#    }
# </style>

# %% [markdown]
# **DATA TYPES**

# %% [markdown]
# | Type|Name|Example
# | :--- |:--- |:---
# | Integer|int|1, 2, 5 , 10, 21235
# | Float|float|0.5, 1.2, 8.0
# | Boolean|bool|True, False
# | String|str|"DNA", "ATCGA"
# | List|list|[1,2,3], ["A","T","C","G"]
# | Dictionary|dict|{1:"A",2:"B"}

# %% [markdown]
# **INTEGERS**

# %%
type(3)
# Out:
# int

# %%
mynumber=5
print(mynumber)
# Out:
# 5

# %%
number1=10
number2=45

number1+number2
# Out:
# 55

# %%
number1*number2
# Out:
# 450

# %%
number2/number1
# Out:
# 4.5

# %%
number2-number1
# Out:
# 35

# %%
total=6+5

# %%
print(total)
# Out:
# 11

# %% [markdown]
# **Float**

# %%
myfloat1=0.9
type(myfloat1)
# Out:
# float

# %%
9.1+2.8
# Out:
# 11.899999999999999

# %%
int(2*2.5)
# Out:
# 5

# %%
myinteger=10
myfloat=2.87

# %%
float(myinteger)
# Out:
# 10.0

# %%
int(myfloat)
# Out:
# 2

# %%
"2" 2

# %%
type("2")
# Out:
# str

# %%
type(2)
# Out:
# int

# %%
int("2")
# Out:
# 2

# %%
float("0.5")
# Out:
# 0.5

# %% [markdown]
# **Boolean values**

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %% [markdown]
# **Mathematical Operations**

# %% [markdown]
# | Operation|Key|
# | :--- |:--- |
# | Addition|+|
# | Subtraction|-|
# | Multiplication|*|
# | Division|/|

# %% [markdown]
# **Logical Operations**

# %% [markdown]
# | Logical operator|Meaning|
# | :--- |:--- |
# | <|Less than|
# | >|Greater than|
# | <=|Less than or equal to|
# | >=|Greater than or equal to|
# | ==|Equal to|
# | !=|Not equal to|

# %%
apples=10
Oranges=5
grapes=5

# %%
#are the number of apples greater than 5?
apples>5
# Out:
# True

# %%
#is the number of grapes equal to the number of oranges?
grapes==Oranges
# Out:
# True

# %%
#is the product of 2 and 6 greater or equal to 9?
(2*6)>=9
# Out:
# True

# %%
#is the number of apples equal to number of grapes
apples==grapes
# Out:
# False
